# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn

# %%
data = pd.read_csv(r"C:\Users\chowd\Desktop\ml-course\data\matches.csv")
data.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
data.drop(columns = ["match_type", "target_runs", "target_overs", "super_over", "method", "umpire1", "umpire2"], inplace = True)

# %%
data.head()
# Out:
#        id   season        city        date player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# ...

# %%
data.drop(columns = ["player_of_match"], inplace = True)

# %%
data.head()
# Out:
#        id   season        city        date  \
# 0  335982  2007/08   Bangalore  2008-04-18
# 1  335983  2007/08  Chandigarh  2008-04-19
# 2  335984  2007/08       Delhi  2008-04-19
# 3  335985  2007/08      Mumbai  2008-04-20
# 4  335986  2007/08     Kolkata  2008-04-20
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# ...

# %%
data.dtypes
# Out:
# id                 int64
# season            object
# city              object
# date              object
# venue             object
# team1             object
# team2             object
# toss_winner       object
# toss_decision     object
# winner            object
# result            object
# result_margin    float64
# dtype: object

# %%
data["date"] = data["date"].astype("datetime64[ns]")

# %%
data.dtypes
# Out:
# id                        int64
# season                   object
# city                     object
# date             datetime64[ns]
# venue                    object
# team1                    object
# team2                    object
# toss_winner              object
# toss_decision            object
# winner                   object
# result                   object
# result_margin           float64
# dtype: object

# %%
data.head()
data.to_csv(r"C:\Users\chowd\Desktop\ml-course\data\IPL datasets.csv", index = False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1095 non-null   int64
#  1   season         1095 non-null   object
#  2   city           1044 non-null   object
#  3   date           1095 non-null   datetime64[ns]
#  4   venue          1095 non-null   object
#  5   team1          1095 non-null   object
#  6   team2          1095 non-null   object
#  7   toss_winner    1095 non-null   object
#  8   toss_decision  1095 non-null   object
#  9   winner         1090 non-null   object
#  10  result         1095 non-null   object
#  11  result_margin  1076 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9)
# memory usage: 102.8+ KB

# %%
data.isna().sum()
# Out:
# id                0
# season            0
# city             51
# date              0
# venue             0
# team1             0
# team2             0
# toss_winner       0
# toss_decision     0
# winner            5
# result            0
# result_margin    19
# dtype: int64

# %%
nan_rows = data[data.isna().any(axis=1)]
nan_rows
# Out:
#           id   season       city       date  \
# 66    392190     2009  Cape Town 2009-04-23
# 130   419121  2009/10    Chennai 2010-03-21
# 241   501265     2011      Delhi 2011-05-21
# 328   598004     2013  Hyderabad 2013-04-07
# 342   598017     2013  Bangalore 2013-04-16
# ..       ...      ...        ...        ...
# 811  1216495  2020/21        NaN 2020-11-03
# 812  1237177  2020/21        NaN 2020-11-05
# 815  1237181  2020/21        NaN 2020-11-10
# 835  1254077     2021    Chennai 2021-04-25
# 994  1359519     2023    Lucknow 2023-05-03
#
#                                                  venue  \
# 66                                            Newlands
# 130                    MA Chidambaram Stadium, Chepauk
# 241                                   Feroz Shah Kotla
# 328          Rajiv Gandhi International Stadium, Uppal
# 342                              M Chinnaswamy Stadium
# ..                                                 ...
# ...

# %%
data[data["city"].isna()].head()
# Out:
#          id season city       date                                venue  \
# 399  729281   2014  NaN 2014-04-17              Sharjah Cricket Stadium
# 402  729287   2014  NaN 2014-04-19  Dubai International Cricket Stadium
# 403  729289   2014  NaN 2014-04-19  Dubai International Cricket Stadium
# 404  729291   2014  NaN 2014-04-20              Sharjah Cricket Stadium
# 406  729295   2014  NaN 2014-04-22              Sharjah Cricket Stadium
#
#                            team1                        team2  \
# 399             Delhi Daredevils  Royal Challengers Bangalore
# 402  Royal Challengers Bangalore               Mumbai Indians
# 403        Kolkata Knight Riders             Delhi Daredevils
# 404             Rajasthan Royals              Kings XI Punjab
# 406              Kings XI Punjab          Sunrisers Hyderabad
#
#                      toss_winner toss_decision                       winner  \
# 399  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# ...

# %%
season_winner = data.drop_duplicates(subset= ["season"], keep = "last")[["season", "winner"]].sort_values("season")
season_winner.reset_index(drop = True, inplace = True)
season_winner
# Out:
#      season                 winner
# 0   2007/08       Rajasthan Royals
# 1      2009        Deccan Chargers
# 2   2009/10    Chennai Super Kings
# 3      2011    Chennai Super Kings
# 4      2012  Kolkata Knight Riders
# 5      2013         Mumbai Indians
# 6      2014  Kolkata Knight Riders
# 7      2015         Mumbai Indians
# 8      2016    Sunrisers Hyderabad
# 9      2017         Mumbai Indians
# 10     2018    Chennai Super Kings
# 11     2019         Mumbai Indians
# 12  2020/21         Mumbai Indians
# 13     2021    Chennai Super Kings
# 14     2022         Gujarat Titans
# 15     2023    Chennai Super Kings
# 16     2024  Kolkata Knight Riders

# %%
season_winner["winner"].value_counts()
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
data
# Out:
#            id   season        city       date  \
# 0      335982  2007/08   Bangalore 2008-04-18
# 1      335983  2007/08  Chandigarh 2008-04-19
# 2      335984  2007/08       Delhi 2008-04-19
# 3      335985  2007/08      Mumbai 2008-04-20
# 4      335986  2007/08     Kolkata 2008-04-20
# ...       ...      ...         ...        ...
# 1090  1426307     2024   Hyderabad 2024-05-19
# 1091  1426309     2024   Ahmedabad 2024-05-21
# 1092  1426310     2024   Ahmedabad 2024-05-22
# 1093  1426311     2024     Chennai 2024-05-24
# 1094  1426312     2024     Chennai 2024-05-26
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# ...

# %%
import re

# Dictionary of patterns and their replacements
patterns_to_replace = {
    r'M[\s.]?Chinnaswamy Stadium.*': 'M. Chinnaswamy Stadium',
    r'Wankhede.*Stadium.*': 'Wankhede International Stadium',
    r'Feroz Shah Kotla.*': 'Arun Jaitley Stadium',
    r'Arun Jaitley Stadium.*': 'Arun Jaitley Stadium',
    r'Eden.*Garden.*': 'Enden Garden',
    r'Dr DY Patil Sports Academy.*':'Dr DY Patil Sports Academy',
    r'Rajiv Gandhi International Stadium.*': 'Rajiv Gandhi International Stadium',
    r'MA Chidambaram Stadium.*': 'MA Chidambaram Stadium'
    
}

# Iterate through the dictionary and apply the replacements
for pattern, replacement in patterns_to_replace.items():
    data['venue'] = data['venue'].replace(to_replace=pattern, value=replacement, regex=True)

# %%
data.drop_duplicates(subset=["venue"])
# Out:
#            id   season            city       date  \
# 0      335982  2007/08       Bangalore 2008-04-18
# 1      335983  2007/08      Chandigarh 2008-04-19
# 2      335984  2007/08           Delhi 2008-04-19
# 3      335985  2007/08          Mumbai 2008-04-20
# 4      335986  2007/08         Kolkata 2008-04-20
# 5      335987  2007/08          Jaipur 2008-04-21
# 6      335988  2007/08       Hyderabad 2008-04-22
# 7      335989  2007/08         Chennai 2008-04-23
# 12     335994  2007/08          Mumbai 2008-04-27
# 58     392181     2009       Cape Town 2009-04-18
# 62     392185     2009  Port Elizabeth 2009-04-20
# 63     392186     2009          Durban 2009-04-21
# 73     392198     2009       Centurion 2009-04-28
# 78     392203     2009     East London 2009-05-01
# 81     392206     2009    Johannesburg 2009-05-02
# 91     392216     2009       Kimberley 2009-05-09
# 101    392226     2009    Bloemfontein 2009-05-15
# 116    419107  2009/10          Mumbai 2010-03-13
# ...

# %%
data["venue"]
# Out:
# 0                           M. Chinnaswamy Stadium
# 1       Punjab Cricket Association Stadium, Mohali
# 2                             Arun Jaitley Stadium
# 3                   Wankhede International Stadium
# 4                                     Enden Garden
#                            ...
# 1090            Rajiv Gandhi International Stadium
# 1091              Narendra Modi Stadium, Ahmedabad
# 1092              Narendra Modi Stadium, Ahmedabad
# 1093                        MA Chidambaram Stadium
# 1094                        MA Chidambaram Stadium
# Name: venue, Length: 1095, dtype: object

# %%
Titanic = pd.read_csv("data/Titanic-Dataset.csv")
Titanic.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 Titanic = pd.read_csv("data/Titanic-Dataset.csv")
#       2 Titanic.head()
#
# File ~\Desktop\ml-course\env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import matplotlib.pyplot as plt
Titanic["Sex"].value_counts().plot(kind='pie',autopct="%.2f");

# %%
Titanic["Survived"].value_counts().plot(kind = 'bar');

# %%
Titanic["Age"].plot(kind='hist',bins =8);

# %%
plt.hist(Titanic['Age'],bins=8);

# %%
Titanic.isna().sum()

# %%
from ydata_profiling import ProfileReport
# Report = ProfileReport(Titanic, correlations={"auto": {"calculate": False}})
# Report.to_file(output_file='Titanic_Report.html')

# %%
# Convert categorical columns like "Embarked" using one-hot encoding
Titanic_encoded = pd.get_dummies(Titanic, columns=['Embarked','Sex'])

# Generate the profiling report with the encoded dataset
Report = ProfileReport(Titanic_encoded)

# Export the report to an HTML file
Report.to_file(output_file='Titanic_Report2.html')

# %%
Titanic_encoded.head()

# %%
# Filter rows where Embarked_C, Embarked_Q, and Embarked_S are all False
filtered_rows = Titanic_encoded[(Titanic_encoded['Embarked_C'] == False) & 
                                (Titanic_encoded['Embarked_Q'] == False) & 
                                (Titanic_encoded['Embarked_S'] == False)]

# Display the filtered rows
filtered_rows

# %%
Titanic.head(100)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
cat_feature = ["Sex", "Embarked"]

one_hot = OneHotEncoder()
Transformer = ColumnTransformer([
    ('one_hot', one_hot, cat_feature)

],remainder = 'passthrough')



transfer_titanic = Transformer.fit_transform(Titanic)

# %%
transfer_titanic.shape

# %%
pd.DataFrame(transfer_titanic)

# %%
Titanic.shape

# %%
Titanic.head()

# %%
Titanic["Embarked"].value_counts()

# %%
Titanic.isna().sum()

# %%
transfer_titanic.shape

# %%
Titanic_encoded.shape
